# %%
import pandas as pd
cost_of_living_df = pd.read_csv('Cost of Living.csv')
gdp_growth_rate_df = pd.read_csv('GDP_Growth_Rate_Final.csv')
gdp_per_capita_df = pd.read_csv('GDP_Per_Capita_Final.csv')
inflation_rate_df = pd.read_csv('Inflation_Rate_Final.csv')
unemployment_rate_df = pd.read_csv('Unemployment_Rate_Final.csv')

merged_df = pd.merge(gdp_growth_rate_df, inflation_rate_df, on=['Year', 'Country'], how='outer')
merged_df = pd.merge(merged_df,gdp_per_capita_df , on=['Year', 'Country'], how='outer')
merged_df = pd.merge(merged_df, unemployment_rate_df, on=['Year', 'Country'], how='outer')
merged_df = pd.merge(merged_df, cost_of_living_df, on=['Year', 'Country'], how='outer')

merged_df.to_csv('Economic_data.csv', index=False)

# %%
pip install miceforest
# Out:
# Requirement already satisfied: miceforest in c:\users\admin\anaconda3\envs\ease\lib\site-packages (6.0.3)
# Requirement already satisfied: lightgbm>=4.1.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from miceforest) (4.6.0)
# Requirement already satisfied: pandas>=2.1.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from miceforest) (2.3.3)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from miceforest) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from miceforest) (1.16.2)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from miceforest) (21.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from pandas>=2.1.0->miceforest) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from pandas>=2.1.0->miceforest) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from pandas>=2.1.0->miceforest) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->miceforest) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\admin\anaconda3\envs\ease\lib\site-packages (2.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio bayesian-torch
# Out:
# Requirement already satisfied: torch in c:\users\admin\anaconda3\envs\ease\lib\site-packages (2.9.0)
# Requirement already satisfied: torchvision in c:\users\admin\anaconda3\envs\ease\lib\site-packages (0.24.0)
# Requirement already satisfied: torchaudio in c:\users\admin\anaconda3\envs\ease\lib\site-packages (2.9.0)
# Requirement already satisfied: bayesian-torch in c:\users\admin\anaconda3\envs\ease\lib\site-packages (0.5.0)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: tensorboard>=1.15.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from bayesian-torch) (2.14.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from bayesian-torch) (1.7.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from scikit-learn>=0.20.3->bayesian-torch) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from scikit-learn>=0.20.3->bayesian-torch) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from scikit-learn>=0.20.3->bayesian-torch) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (1.75.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (3.9)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (2.32.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (80.9.0)
# Requirement already satisfied: six>1.9 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from tensorboard>=1.15.0->bayesian-torch) (3.1.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15.0->bayesian-torch) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15.0->bayesian-torch) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15.0->bayesian-torch) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15.0->bayesian-torch) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=1.15.0->bayesian-torch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=1.15.0->bayesian-torch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=1.15.0->bayesian-torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=1.15.0->bayesian-torch) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard>=1.15.0->bayesian-torch) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15.0->bayesian-torch) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=1.15.0->bayesian-torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install miceforest==4.0.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following yanked versions: 1.0.7
# ERROR: Could not find a version that satisfies the requirement miceforest==4.0.0 (from versions: 0.9000, 1.0.3, 1.0.4, 1.0.5, 1.0.6, 1.0.8, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.0.5, 2.0.6, 3.0.0, 3.0.1, 3.1.1, 4.0.1, 4.0.2, 4.0.3, 4.0.4, 5.0.0, 5.0.1, 5.0.2, 5.0.3, 5.1.0, 5.1.1, 5.1.2, 5.2.0, 5.2.1, 5.2.2, 5.3.0, 5.3.1, 5.4.0, 5.5.0, 5.5.1, 5.5.2, 5.5.3, 5.5.4, 5.6.0, 5.6.1, 5.6.2, 5.6.3, 5.7.0, 6.0.1, 6.0.2, 6.0.3)
# ERROR: No matching distribution found for miceforest==4.0.0

# %%
pip install plotnine
# Out:
# Requirement already satisfied: plotnine in c:\users\admin\anaconda3\envs\ease\lib\site-packages (0.15.0)
# Requirement already satisfied: matplotlib>=3.8.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from plotnine) (3.10.7)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from plotnine) (2.3.3)
# Requirement already satisfied: mizani~=0.14.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from plotnine) (0.14.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from plotnine) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from plotnine) (1.16.2)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from plotnine) (0.14.5)
# Requirement already satisfied: tzdata in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from mizani~=0.14.0->plotnine) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from matplotlib>=3.8.0->plotnine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from pandas>=2.2.0->plotnine) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->plotnine) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\admin\anaconda3\envs\ease\lib\site-packages (from statsmodels>=0.14.5->plotnine) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
