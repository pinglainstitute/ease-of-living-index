# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from factor_analyzer import FactorAnalyzer, calculate_kmo, calculate_bartlett_sphericity

# %%
df = pd.read_csv("imputed_data_Economic.csv")

# Interpolate missing numeric values linearly
df = df.interpolate(method='linear', limit_direction='forward', axis=0)

# Select only numeric columns for FA
df_numeric = df.drop(columns=['Country', 'Year'])

# Standardize the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_numeric)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 df = pd.read_csv("imputed_data_Economic.csv")
#       3 # Interpolate missing numeric values linearly
# ----> 4 df = df.interpolate(method='linear', limit_direction='forward', axis=0)
#       6 # Select only numeric columns for FA
#       7 df_numeric = df.drop(columns=['Country', 'Year'])
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/generic.py:8065, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, **kwargs)
#    8062 limit_direction = missing.infer_limit_direction(limit_direction, method)
#    8064 index = missing.get_interp_index(method, obj.index)
# -> 8065 new_data = obj._mgr.interpolate(
#    8066     method=method,
#    8067     index=index,
#    8068     limit=limit,
#    8069     limit_direction=limit_direction,
#    8070     limit_area=limit_area,
#    8071     inplace=inplace,
#    8072     **kwargs,
#    8073 )
#    8075 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8076 if should_transpose:
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/internals/managers.py:538, in BaseBlockManager.interpolate(self, inplace, **kwargs)
#     537 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 538     return self.apply("interpolate", inplace=inplace, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:1404, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, **kwargs)
#    1401 copy, refs = self._get_refs_and_copy(inplace)
#    1403 # Dispatch to the EA method.
# -> 1404 new_values = self.array_values.interpolate(
#    1405     method=method,
#    1406     axis=self.ndim - 1,
#    1407     index=index,
#    1408     limit=limit,
#    1409     limit_direction=limit_direction,
#    1410     limit_area=limit_area,
#    1411     copy=copy,
#    1412     **kwargs,
#    1413 )
#    1414 data = extract_array(new_values, extract_numpy=True)
#    1415 return [self.make_block_same_class(data, refs=refs)]
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/arrays/numpy_.py:348, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     346 # NB: we return type(self) even if copy=False
#     347 if not self.dtype._is_numeric:
# --> 348     raise TypeError(f"Cannot interpolate with {self.dtype} dtype")
#     350 if not copy:
#     351     out_data = self._ndarray
#
# TypeError: Cannot interpolate with str dtype

# %%
kmo_all, kmo_model = calculate_kmo(df_scaled)
print("KMO Test:", kmo_model) 

chi_square_value, p_value = calculate_bartlett_sphericity(df_scaled)
print("Bartlett’s Test Chi-square:", chi_square_value, "p-value:", p_value)
# Out:
# KMO Test: 0.7329814748651801
# Bartlett’s Test Chi-square: 29881.27732276119 p-value: 0.0

# %%
corr_matrix = np.corrcoef(df_scaled.T)
eigenvalues, _ = np.linalg.eig(corr_matrix)
print("Eigenvalues:", eigenvalues)

# Scree plot
plt.figure(figsize=(8,5))
plt.plot(range(1, len(eigenvalues)+1), eigenvalues, 'o-', color='blue')
plt.axhline(y=1, color='red', linestyle='--', label='Kaiser criterion (Eigenvalue=1)')
plt.title('Scree Plot')
plt.xlabel('Factor Number')
plt.ylabel('Eigenvalue')
plt.xticks(range(1, len(eigenvalues)+1))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Eigenvalues: [2.68637465 1.09974137 1.00424088 0.90043577 0.19265186 0.11655547]

# %%
n_factors = np.sum(eigenvalues > 1)  # Kaiser criterion

# %%
fa = FactorAnalyzer(n_factors=n_factors, rotation='varimax')
fa.fit(df_scaled)
# Out:
# C:\Users\Admin\anaconda3\envs\Ease\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# FactorAnalyzer(rotation='varimax', rotation_kwargs={})

# %%
loadings = pd.DataFrame(fa.loadings_, index=df_numeric.columns, columns=[f'Factor{i+1}' for i in range(n_factors)])
print("\nFactor Loadings:\n", loadings)

# Variance 
variance = pd.DataFrame(fa.get_factor_variance(), 
                        index=['Variance', 'Proportional Variance', 'Cumulative Variance'], 
                        columns=[f'Factor{i+1}' for i in range(n_factors)])
print("\nVariance Explained:\n", variance)
# Out:
# Factor Loadings:
#                                 Factor1   Factor2   Factor3
# Inflation_Rate               -0.027361  0.994209  0.076258
# GDP_Per_Capita                0.962161  0.001705  0.032288
# GDP_Growth_Rate              -0.054126 -0.048189 -0.122706
# Unemployment_Rate            -0.039219 -0.054578  0.716476
# Cost of Living Index          0.894722  0.028010  0.036586
# Local Purchasing Power Index  0.884041 -0.026711  0.195789
#
# Variance Explained:
#                          Factor1   Factor2   Factor3
# Variance               2.513026  0.995253  0.574924
# Proportional Variance  0.418838  0.165876  0.095821
# Cumulative Variance    0.418838  0.584713  0.680534
